# %%
# %sql
CREATE TABLE IF NOT EXISTS sales_data_project.sales_data.sales_data_raw;

# %%
# %sql
COPY INTO sales_data_project.sales_data.sales_data_raw
FROM '/Volumes/sales_data_project/sales_data/source_data_csv/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true', 'inferSchema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
