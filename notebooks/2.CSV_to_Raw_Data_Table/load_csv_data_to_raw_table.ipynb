# %% [markdown]
# **This notebook creates the raw data landing table and incrementally loads converted csv file data into landing delta table**

# %%
# %sql
CREATE TABLE IF NOT EXISTS sales_data_project.sales_data.sales_data_landing;

# %%
# %sql
COPY INTO sales_data_project.sales_data.sales_data_landing
FROM '/Volumes/sales_data_project/sales_data/source_data_csv/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true', 'inferSchema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
